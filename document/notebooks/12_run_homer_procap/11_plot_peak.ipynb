# %%
suppressMessages(suppressWarnings(source("config.R")))

# %%
gene_sel = c(
    "CIDEC", "PER1", "ANGPTL4", "TSC22D3", "STOM", "ZFP36", "NFKBIA",
    "JUN", "FOSL1",  "CCL2", "IL11")
length(gene_sel)
# Out:
# [1] 11

# %%
gene_pos = c(
    "CIDEC", 
    "PER1", 
    "EKI2", "ETNK2",
    "ANGPTL4",
    "TSC22D3",
    "RGS2",
    "CDC42EP3",
    "STOM",
    "THBD",
    "DUSP1",
    "GADD45A",
    "KLF4",
    "ZFP36",
    "ERRFI1",
    "SDPR",
    "CTGF",
    "NFKBIA",
    "BIPARP",
    "BIRC3",
    "BCL6",
    "ELL2",
    "CEBPB",
    "CEBPD",
    "CITED2",
    "ARL4D",
    "GALNT4",
    "KLF6",
    "ZC3H12A")

# %%
gene_neg = c(
    "IL11",
    "RND1",
    "CCL2",
    "MAP3K14",
    "SNKPLK2",
    "GEM",
    "IER3",
    "IER2",
    "ELF3",
    "IER5L",
    "FOSL1",
    "JUN",
    "HES1",
    "ENC1",
    "SERTAD3",
    "BHLHE40",
    "BCL3",
    "KLF10"
)

# %%
fpath = "/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_annotate/annoTSS/tss_count_raw.txt"
dat_raw = read_tsv(fpath)
head(dat_raw, 3)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   Start = col_double(),
#   End = col_double(),
#   `Peak Score` = col_double(),
#   `Distance to TSS` = col_double(),
#   `Entrez ID` = col_double(),
#   `/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ Tag Count in given bp (9384553.0 Total, normalization factor = 1, effective total = 10000000)` = col_double(),
#   `/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ Tag Count in given bp (9252351.5 Total, normalization factor = 1, effective total = 10000000)` = col_double(),
#   `/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/ Tag Count in given bp (13741782.5 Total, normalization factor = 1, effective total = 10000000)` = col_double()
# )
# See spec(...) for full column specifications.
#   PeakID (cmd=annotatePeaks.pl /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergeTSS/tss_merge.txt hg38 -strand + -fragLength 1 -raw -d /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/)
# 1 Merged-chr14-49862550-3
# 2 Merged-chr14-49862849-3
# 3 Merged-chr17-19188010-3
#   Chr   Start    End      Strand Peak Score
# 1 chr14 49862475 49862625 +      5036.000
# 2 chr14 49862774 49862924 -      4960.967
# 3 chr17 19187935 19188085 +      3358.767
#   Focus Ratio/Region Size
# 1 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
# 2 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
# 3 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
#   Annotation               Detailed Annotation      Distance to TSS ...
# 1 TTS (NR_027260)          TTS (NR_027260)          299             ...
# 2 promoter-TSS (NR_027260) promoter-TSS (NR_027260)   0             ...
# 3 promoter-TSS (NR_006880) promoter-TSS (NR_006880)  -6             ...
#   Nearest Unigene Nearest Refseq Nearest Ensembl Gene Name
# 1 NA              NR_027260      ENSG00000274012 RN7SL2
# 2 NA              NR_027260      ENSG00000274012 RN7SL2
# 3 NA              NR_006880      ENSG00000263934 SNORD3A
#   Gene Alias               Gene Description
# 1 7L1C|7L30.1|7SL1c|RNSRP2 RNA component of signal recognition particle 7SL2
# 2 7L1C|7L30.1|7SL1c|RNSRP2 RNA component of signal recognition particle 7SL2
# 3 RNU3|U3                  small nucleolar RNA, C/D box 3A
#   Gene Type
# 1 scRNA
# 2 scRNA
# 3 snoRNA
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ Tag Count in given bp (9384553.0 Total, normalization factor = 1, effective total = 10000000)
# 1 6259
# 2 4608
# 3 4068
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ Tag Count in given bp (9252351.5 Total, normalization factor = 1, effective total = 10000000)
# 1 4545.5
# 2 3442.5
# 3 3830.5
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/ Tag Count in given bp (13741782.5 Total, normalization factor = 1, effective total = 10000000)
# 1 4832.5
# 2 4541.0
# 3 2131.5

# %%
fpath = "/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_annotate/annoTSS/tss_count_rlg.txt"
dat_rlg = read_tsv(fpath)
head(dat_rlg, 3)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   Start = col_double(),
#   End = col_double(),
#   `Peak Score` = col_double(),
#   `Distance to TSS` = col_double(),
#   `Entrez ID` = col_double(),
#   `/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ Tag Count in given bp (9384553.0 Total, normalization factor = 1, effective total = 10000000)` = col_double(),
#   `/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ Tag Count in given bp (9252351.5 Total, normalization factor = 1, effective total = 10000000)` = col_double(),
#   `/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/ Tag Count in given bp (13741782.5 Total, normalization factor = 1, effective total = 10000000)` = col_double()
# )
# See spec(...) for full column specifications.
#   PeakID (cmd=annotatePeaks.pl /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergeTSS/tss_merge.txt hg38 -strand + -fragLength 1 -rlog -d /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/)
# 1 Merged-chr14-49862550-3
# 2 Merged-chr14-49862849-3
# 3 Merged-chr17-19188010-3
#   Chr   Start    End      Strand Peak Score
# 1 chr14 49862475 49862625 +      5036.000
# 2 chr14 49862774 49862924 -      4960.967
# 3 chr17 19187935 19188085 +      3358.767
#   Focus Ratio/Region Size
# 1 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
# 2 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
# 3 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
#   Annotation               Detailed Annotation      Distance to TSS ...
# 1 TTS (NR_027260)          TTS (NR_027260)          299             ...
# 2 promoter-TSS (NR_027260) promoter-TSS (NR_027260)   0             ...
# 3 promoter-TSS (NR_006880) promoter-TSS (NR_006880)  -6             ...
#   Nearest Unigene Nearest Refseq Nearest Ensembl Gene Name
# 1 NA              NR_027260      ENSG00000274012 RN7SL2
# 2 NA              NR_027260      ENSG00000274012 RN7SL2
# 3 NA              NR_006880      ENSG00000263934 SNORD3A
#   Gene Alias               Gene Description
# 1 7L1C|7L30.1|7SL1c|RNSRP2 RNA component of signal recognition particle 7SL2
# 2 7L1C|7L30.1|7SL1c|RNSRP2 RNA component of signal recognition particle 7SL2
# 3 RNU3|U3                  small nucleolar RNA, C/D box 3A
#   Gene Type
# 1 scRNA
# 2 scRNA
# 3 snoRNA
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ Tag Count in given bp (9384553.0 Total, normalization factor = 1, effective total = 10000000)
# 1 12.64921
# 2 12.20911
# 3 12.02521
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ Tag Count in given bp (9252351.5 Total, normalization factor = 1, effective total = 10000000)
# 1 12.18962
# 2 11.79050
# 3 11.93491
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/ Tag Count in given bp (13741782.5 Total, normalization factor = 1, effective total = 10000000)
# 1 12.15269
# 2 12.05929
# 3 10.98238

# %%
dat = dat_raw %>% dplyr::filter(`Gene Name`=="PER1", grepl(x = `Detailed Annotation`, pattern="promoter"))
head(dat)
# Out:
#   PeakID (cmd=annotatePeaks.pl /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergeTSS/tss_merge.txt hg38 -strand + -fragLength 1 -raw -d /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/)
# 1 Merged-chr17-8152395-3
# 2 Merged-chr17-8152344-3
#   Chr   Start   End     Strand Peak Score
# 1 chr17 8152319 8152471 -      187.0333
# 2 chr17 8152268 8152421 +      184.5333
#   Focus Ratio/Region Size
# 1 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
# 2 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
#   Annotation               Detailed Annotation      Distance to TSS ...
# 1 promoter-TSS (NM_002616) promoter-TSS (NM_002616)  9              ...
# 2 promoter-TSS (NM_002616) promoter-TSS (NM_002616) 60              ...
#   Nearest Unigene Nearest Refseq Nearest Ensembl Gene Name Gene Alias
# 1 Hs.445534       NM_002616      ENSG00000179094 PER1      PER|RIGUI|hPER
# 2 Hs.445534       NM_002616      ENSG00000179094 PER1      PER|RIGUI|hPER
#   Gene Description             Gene Type
# 1 period circadian regulator 1 protein-coding
# 2 period circadian regulator 1 protein-coding
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ Tag Count in given bp (9384553.0 Total, normalization factor = 1, effective total = 10000000)
# 1 270.0
# 2 267.5
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ Tag Count in given bp (9252351.5 Total, normalization factor = 1, effective total = 10000000)
# 1 157
# 2 153
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/ Tag Count in given bp (13741782.5 Total, normalization factor = 1, effective total = 10000000)
# 1 142.5
# 2 142.5

# %%
# Out:
#  [1] "KLF6"     "ERRFI1"   "CEBPB"    "DUSP1"    "NFKBIA"   "CITED2"
#  [7] "ELL2"     "TSC22D3"  "ZC3H12A"  "RGS2"     "KLF4"     "GADD45A"
# [13] "PER1"     "ARL4D"    "CEBPD"    "ZFP36"    "BCL6"     "STOM"
# [19] "GALNT4"   "ANGPTL4"  "CDC42EP3" "ETNK2"    "BIRC3"
#   PeakID (cmd=annotatePeaks.pl /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergeTSS/tss_merge.txt hg38 -strand + -fragLength 1 -rlog -d /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/)
# 1 Merged-chr10-3785548-3
# 2 Merged-chr10-3785640-3
# 3 Merged-chr1-8026309-3
#   Chr   Start   End     Strand Peak Score
# 1 chr10 3785473 3785623 +      1499.967
# 2 chr10 3785565 3785715 -      1457.200
# 3 chr1  8026234 8026384 -      1448.333
#   Focus Ratio/Region Size
# 1 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
# 2 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
# 3 /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap00/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap15/out.tss.txt|/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findTSS/tss_cap60/out.tss.txt
#   Annotation                  Detailed Annotation         Distance to TSS ...
# 1 promoter-TSS (NM_001160124) promoter-TSS (NM_001160124) -267            ...
# 2 promoter-TSS (NM_001160124) promoter-TSS (NM_001160124) -359            ...
# 3 promoter-TSS (NM_018948)    promoter-TSS (NM_018948)       0            ...
#   Nearest Unigene Nearest Refseq Nearest Ensembl Gene Name
# 1 Hs.4055         NM_001300      ENSG00000067082 KLF6
# 2 Hs.4055         NM_001300      ENSG00000067082 KLF6
# 3 Hs.605445       NM_018948      ENSG00000116285 ERRFI1
#   Gene Alias                             Gene Description
# 1 BCD1|CBA1|COPEB|CPBP|GBF|PAC1|ST12|ZF9 Kruppel like factor 6
# 2 BCD1|CBA1|COPEB|CPBP|GBF|PAC1|ST12|ZF9 Kruppel like factor 6
# 3 GENE-33|MIG-6|MIG6|RALT                ERBB receptor feedback inhibitor 1
#   Gene Type
# 1 protein-coding
# 2 protein-coding
# 3 protein-coding
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t00/ Tag Count in given bp (9384553.0 Total, normalization factor = 1, effective total = 10000000)
# 1 10.82983
# 2 10.77416
# 3 10.90958
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t15/ Tag Count in given bp (9252351.5 Total, normalization factor = 1, effective total = 10000000)
# 1 10.55190
# 2 10.52095
# 3 10.45608
#   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/tags/procap_t60/ Tag Count in given bp (13741782.5 Total, normalization factor = 1, effective total = 10000000)
# 1 10.37947
# 2 10.36860
# 3 10.10912

# %%
dat = dat_raw
dat = dat %>% dplyr::filter(`Gene Name` %in% gene_pos, grepl(x = `Detailed Annotation`, pattern="promoter"))
dat = dat %>% dplyr::select(
    Chr, Start, End, Strand, `Gene Name`, 
    starts_with("/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer")) %>%
    unite("loc", Chr:Strand)
colnames(dat) = c("loc", "gene", "t00", "t15", "t60")

dat = dat %>% gather(time_point, count, -gene, -loc)
dat$gene = factor(dat$gene, levels=gene_pos)
head(dat)
# Out:
#   loc                       gene   time_point count
# 1 chr10_3785473_3785623_+   KLF6   t00        1777.0
# 2 chr10_3785565_3785715_-   KLF6   t00        1709.0
# 3 chr1_8026234_8026384_-    ERRFI1 t00        1886.0
# 4 chr1_8026190_8026357_+    ERRFI1 t00        1640.5
# 5 chr20_50190749_50190902_+ CEBPB  t00         824.0
# 6 chr20_50190790_50190940_- CEBPB  t00         784.0

# %%
options(repr.plot.height=5, repr.plot.width=7)
gpt = ggplot(dat, aes(x=time_point, y=count, color=gene, group=loc)) + 
    geom_line() +
    theme_bw() + 
    labs(x="Time Point", y="Peak Count (raw)")
    
print(gpt)
# Out:
# plot without title

# %%
dat = dat_rlg
dat = dat %>% dplyr::filter(`Gene Name` %in% gene_pos, grepl(x = `Detailed Annotation`, pattern="promoter"))
dat = dat %>% dplyr::select(
    Chr, Start, End, Strand, `Gene Name`, 
    starts_with("/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer")) %>%
    unite("loc", Chr:Strand)
colnames(dat) = c("loc", "gene", "t00", "t15", "t60")

dat = dat %>% gather(time_point, count, -gene, -loc)
dat$gene = factor(dat$gene, levels=gene_pos)
head(dat)
# Out:
#   loc                       gene   time_point count
# 1 chr10_3785473_3785623_+   KLF6   t00        10.829829
# 2 chr10_3785565_3785715_-   KLF6   t00        10.774159
# 3 chr1_8026234_8026384_-    ERRFI1 t00        10.909581
# 4 chr1_8026190_8026357_+    ERRFI1 t00        10.708823
# 5 chr20_50190749_50190902_+ CEBPB  t00         9.733247
# 6 chr20_50190790_50190940_- CEBPB  t00         9.662392

# %%
options(repr.plot.height=5, repr.plot.width=7)
gpt = ggplot(dat, aes(x=time_point, y=count, color=gene, group=loc)) + 
    geom_line() +
    theme_bw() + 
    labs(x="Time Point", y="Peak Count (rlg)")
print(gpt)
# Out:
# plot without title

# %%
gene = gene_neg
dat = dat_raw

dat = dat %>% dplyr::filter(`Gene Name` %in% gene, grepl(x = `Detailed Annotation`, pattern="promoter"))
dat = dat %>% dplyr::select(
    Chr, Start, End, Strand, `Gene Name`, 
    starts_with("/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer")) %>%
    unite("loc", Chr:Strand)
colnames(dat) = c("loc", "gene", "t00", "t15", "t60")

dat = dat %>% gather(time_point, count, -gene, -loc)
dat$gene = factor(dat$gene, levels=gene)
head(dat)
# Out:
#   loc                        gene time_point count
# 1 chr1_58783969_58784119_-   JUN  t00        1147.5
# 2 chr1_202010502_202010656_+ ELF3 t00         863.0
# 3 chr1_202010555_202010705_- ELF3 t00         851.5
# 4 chr3_194136067_194136217_+ HES1 t00         700.5
# 5 chr3_194136098_194136258_- HES1 t00         700.0
# 6 chr1_58783921_58784071_+   JUN  t00         960.5

# %%
options(repr.plot.height=5, repr.plot.width=6)
gpt = ggplot(dat, aes(x=time_point, y=count, color=gene, group=loc)) + 
    geom_line() +
    theme_bw() + 
    labs(x="Time Point", y="Peak Count (raw)")
    
print(gpt)
# Out:
# plot without title

# %%
gene = gene_neg
dat = dat_rlg

dat = dat %>% dplyr::filter(`Gene Name` %in% gene, grepl(x = `Detailed Annotation`, pattern="promoter"))
dat = dat %>% dplyr::select(
    Chr, Start, End, Strand, `Gene Name`, 
    starts_with("/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer")) %>%
    unite("loc", Chr:Strand)
colnames(dat) = c("loc", "gene", "t00", "t15", "t60")

dat = dat %>% gather(time_point, count, -gene, -loc)
dat$gene = factor(dat$gene, levels=gene)
head(dat)
# Out:
#   loc                        gene time_point count
# 1 chr1_58783969_58784119_-   JUN  t00        10.165230
# 2 chr1_202010502_202010656_+ ELF3 t00         9.776913
# 3 chr1_202010555_202010705_- ELF3 t00         9.758447
# 4 chr3_194136067_194136217_+ HES1 t00         9.487573
# 5 chr3_194136098_194136258_- HES1 t00         9.485529
# 6 chr1_58783921_58784071_+   JUN  t00         9.906729

# %%
options(repr.plot.height=5, repr.plot.width=6)
gpt = ggplot(dat, aes(x=time_point, y=count, color=gene, group=loc)) + 
    geom_line() +
    theme_bw() + 
    labs(x="Time Point", y="Peak Count (rlg)")
print(gpt)
# Out:
# plot without title
