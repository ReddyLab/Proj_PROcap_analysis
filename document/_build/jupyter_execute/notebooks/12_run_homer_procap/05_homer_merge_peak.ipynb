# %% [markdown]
# # Merge Peak output from HOMER findPeaks

# %%
# %%bash
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
# sbatch -pnew,all \
#     --mem 16G \
#     -o /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/log/mergePeak.txt \
#     <<'EOF'
# #!/bin/bash
#
# ### Set Directories
# FD_OUT=/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer
# FD_PEAK=$FD_OUT/out_findPeak
# FD_MERGE=$FD_OUT/out_merge/mergePeak
#
# FP_TSS_T00=${FD_PEAK}/tss_cap00.txt
# FP_TSS_T15=${FD_PEAK}/tss_cap15.txt
# FP_TSS_T60=${FD_PEAK}/tss_cap60.txt
# FP_TSS_MERGE=${FD_MERGE}/tss_merge.txt
# FP_TSS_SHIFT=${FD_MERGE}/tss_shift.txt
# FP_TSS_SHIST=${FD_MERGE}/tss_shist.txt
#
# ### Merge TSS cluster positions from two separate experiments into
# ### a single set of non-redundant TSS clusters
# # mergePeaks exp1-rep1.tss.txt exp1-rep2.tss.txt exp2-rep1.tss.txt exp2-rep2.tss.txt -strand > merged.tss.txt
# # mergePeaks exp1.tss.txt exp2.tss.txt -strand > merged.tss.txt
# mergePeaks $FP_TSS_T00 $FP_TSS_T15 $FP_TSS_T60 -strand > $FP_TSS_MERGE
#
# EOF
# Out:
# Submitted batch job 24852959

# %%
# %%bash
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
# sbatch -pnew,all \
#     --mem 16G \
#     -o /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/log/mergePeak_rna.txt \
#     <<'EOF'
# #!/bin/bash
#
# ### Set Directories
# FD_OUT=/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer
# FD_PEAK=$FD_OUT/out_findPeak
# FD_MERGE=$FD_OUT/out_merge/mergePeak
#
# FP_TSS_T00=${FD_PEAK}/tss_cap00_rna00.txt
# FP_TSS_T15=${FD_PEAK}/tss_cap15_rna15.txt
# FP_TSS_T60=${FD_PEAK}/tss_cap60_rna60.txt
# FP_TSS_MERGE=${FD_MERGE}/tss_merge_rna.txt
# FP_TSS_SHIFT=${FD_MERGE}/tss_shift_rna.txt
# FP_TSS_SHIST=${FD_MERGE}/tss_shist_rna.txt
#
# ### Merge TSS cluster positions from two separate experiments into
# ### a single set of non-redundant TSS clusters
# # mergePeaks exp1-rep1.tss.txt exp1-rep2.tss.txt exp2-rep1.tss.txt exp2-rep2.tss.txt -strand > merged.tss.txt
# # mergePeaks exp1.tss.txt exp2.tss.txt -strand > merged.tss.txt
# mergePeaks $FP_TSS_T00 $FP_TSS_T15 $FP_TSS_T60 -strand > $FP_TSS_MERGE
#
# EOF
# Out:
# Submitted batch job 24852960

# %% [markdown]
# -----

# %%
# %%bash
# wc -l /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge.txt
# wc -l /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge_rna.txt
# Out:
# wc: /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge.txt: No such file or directory
# wc: /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge_rna.txt: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-3-a252bad593af> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'wc -l /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge.txt\nwc -l /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge_rna.txt\n')
#
# /data/reddylab/Kuei/envs/jupyterhub/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2369             with self.builtin_trap:
#    2370                 args = (magic_arg_s, cell)
# -> 2371                 result = fn(*args, **kwargs)
#    2372             return result
#    2373
#
# /data/reddylab/Kuei/envs/jupyterhub/lib/python3.6/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-110> in shebang(self, line, cell)
#
# /data/reddylab/Kuei/envs/jupyterhub/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /data/reddylab/Kuei/envs/jupyterhub/lib/python3.6/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'wc -l /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge.txt\nwc -l /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge_rna.txt\n'' returned non-zero exit status 1.

# %%
# %%bash
# head /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge.txt
# Out:
# #name (cmd = mergePeaks /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap00.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap15.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt -strand)	chr	start	end	strand	Stat	Parent files	Total subpeaks	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap00.txt	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap15.txt	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt
# Merged-chr14-25238041-1	chr14	25237966	25238116	-	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr14-3108
# Merged-chr14-28318205-1	chr14	28318130	28318280	+	5.090000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr14-3109
# Merged-chr11-14271824-1	chr11	14271749	14271899	-	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr11-4861
# Merged-chr11-14284553-1	chr11	14284478	14284628	+	6.190000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr11-4862
# Merged-chr11-14422588-1	chr11	14422513	14422663	+	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr11-4863
# Merged-chr11-14422640-1	chr11	14422565	14422715	-	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr11-4864
# Merged-chr11-19988702-1	chr11	19988627	19988777	-	6.190000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr11-4869
# Merged-chr1-45647444-1	chr1	45647369	45647519	-	6.190000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr1-9132
# Merged-chr1-46019521-1	chr1	46019446	46019596	+	6.550000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60.txt	1			chr1-9133

# %%
# %%bash
# head /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge_rna.txt
# Out:
# #name (cmd = mergePeaks /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap00_rna00.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap15_rna15.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt -strand)	chr	start	end	strand	Stat	Parent files	Total subpeaks	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap00_rna00.txt	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap15_rna15.txt	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt
# Merged-chr14-25238041-1	chr14	25237966	25238116	-	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr14-3108
# Merged-chr14-28318205-1	chr14	28318130	28318280	+	5.090000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr14-3109
# Merged-chr11-14271824-1	chr11	14271749	14271899	-	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr11-4861
# Merged-chr11-14284553-1	chr11	14284478	14284628	+	6.190000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr11-4862
# Merged-chr11-14422588-1	chr11	14422513	14422663	+	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr11-4863
# Merged-chr11-14422640-1	chr11	14422565	14422715	-	5.820000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr11-4864
# Merged-chr11-19988702-1	chr11	19988627	19988777	-	6.190000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr11-4869
# Merged-chr1-45647444-1	chr1	45647369	45647519	-	6.190000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr1-9132
# Merged-chr1-46019521-1	chr1	46019446	46019596	+	6.550000	/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_cap60_rna60.txt	1			chr1-9133

# %% [markdown]
# -----

# %%
import numpy  as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
fpath = "/gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_merge/mergePeak/tss_merge.txt"
dat = pd.read_csv(fpath, sep="\t")
dat.head(50)
# Out:
# /data/reddylab/Kuei/envs/jupyterhub/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    #name (cmd = mergePeaks /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t00.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t15.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t60.txt -strand)  \
# 0                             Merged-chr14-25238041-1
# 1                             Merged-chr14-28318205-1
# 2                             Merged-chr11-14271824-1
# 3                             Merged-chr11-14284553-1
# 4                             Merged-chr11-14422588-1
# 5                             Merged-chr11-14422640-1
# 6                             Merged-chr11-19988702-1
# 7                              Merged-chr1-45647444-1
# 8                              Merged-chr1-46019521-1
# 9                              Merged-chr1-46485902-1
# 10                             Merged-chr1-47416966-1
# 11                            Merged-chr3-120907769-1
# 12                             Merged-chr1-49006092-1
# 13                            Merged-chr3-123632272-1
# 14                             Merged-chr1-52063367-1
# 15                            Merged-chr3-126852229-1
# 16                            Merged-chr3-126852193-1
# 17                             Merged-chr1-40338840-1
# 18                             Merged-chr1-40772553-1
# 19                            Merged-chr11-46347224-1
# 20                            Merged-chr11-66361599-1
# 21                             Merged-chr1-44592426-1
# 22                            Merged-chr11-67261632-1
# 23                            Merged-chr11-69013088-1
# 24                            Merged-chr11-79473422-1
# 25                             Merged-chr3-68932473-1
# 26                             Merged-chr3-68932545-1
# 27                             Merged-chr3-71785442-1
# 28                            Merged-chr3-117997536-1
# 29                            Merged-chr3-177360133-1
# 30                            Merged-chr14-39140233-1
# 31                            Merged-chr14-39140293-1
# 32                            Merged-chr14-46508556-1
# 33                            Merged-chr14-46508599-1
# 34                            Merged-chr14-47675544-1
# 35                            Merged-chr11-20066291-1
# 36                            Merged-chr11-22432268-1
# 37                            Merged-chr11-25579714-1
# 38                            Merged-chr11-25579870-1
# 39                            Merged-chr11-30056843-1
# 40                            Merged-chr11-30056875-1
# 41                            Merged-chr11-30585947-1
# 42                            Merged-chr11-31836885-1
# 43                            Merged-chr11-31836912-1
# 44                             Merged-chr1-53705649-1
# 45                             Merged-chr1-53705674-1
# 46                             Merged-dm6_X-2470041-1
# 47                             Merged-chr1-56376745-1
# 48                            Merged-chr3-138935929-1
# 49                             Merged-chr1-56376840-1
#
#       chr      start        end strand       Stat  \
# 0   chr14   25237966   25238116      -   5.820000
# 1   chr14   28318130   28318280      +   5.090000
# 2   chr11   14271749   14271899      -   5.820000
# 3   chr11   14284478   14284628      +   6.190000
# 4   chr11   14422513   14422663      +   5.820000
# 5   chr11   14422565   14422715      -   5.820000
# 6   chr11   19988627   19988777      -   6.190000
# 7    chr1   45647369   45647519      -   6.190000
# 8    chr1   46019446   46019596      +   6.550000
# 9    chr1   46485827   46485977      +   6.190000
# 10   chr1   47416891   47417041      -   6.550000
# 11   chr3  120907694  120907844      +   8.730000
# 12   chr1   49006017   49006167      -   6.550000
# 13   chr3  123632197  123632347      -   8.730000
# 14   chr1   52063292   52063442      -   6.550000
# 15   chr3  126852154  126852304      -   8.370000
# 16   chr3  126852118  126852268      +   9.100000
# 17   chr1   40338765   40338915      -   4.730000
# 18   chr1   40772478   40772628      -   5.090000
# 19  chr11   46347149   46347299      -  12.700000
# 20  chr11   66361524   66361674      -  12.000000
# 21   chr1   44592351   44592501      +   5.090000
# 22  chr11   67261557   67261707      +  12.400000
# 23  chr11   69013013   69013163      +  12.700000
# 24  chr11   79473347   79473497      -  12.700000
# 25   chr3   68932398   68932548      +  22.900000
# 26   chr3   68932470   68932620      -  22.600000
# 27   chr3   71785367   71785517      -  22.600000
# 28   chr3  117997461  117997611      +  22.600000
# 29   chr3  177360058  177360208      +  22.200001
# 30  chr14   39140158   39140308      +   5.820000
# 31  chr14   39140218   39140368      -   5.460000
# 32  chr14   46508481   46508631      +   5.820000
# 33  chr14   46508524   46508674      -   5.820000
# 34  chr14   47675469   47675619      +   5.090000
# 35  chr11   20066216   20066366      -   5.820000
# 36  chr11   22432193   22432343      -   5.460000
# 37  chr11   25579639   25579789      +   6.190000
# 38  chr11   25579795   25579945      -   6.190000
# 39  chr11   30056768   30056918      +   6.190000
# 40  chr11   30056800   30056950      -   6.190000
# 41  chr11   30585872   30586022      -   5.820000
# 42  chr11   31836810   31836960      +   6.190000
# 43  chr11   31836837   31836987      -   6.190000
# 44   chr1   53705574   53705724      +   6.550000
# 45   chr1   53705599   53705749      -   6.190000
# 46  dm6_X    2469966    2470116      -  10.200000
# 47   chr1   56376670   56376820      +   6.550000
# 48   chr3  138935854  138936004      +   8.730000
# 49   chr1   56376765   56376915      -   6.550000
#
#                                          Parent files  Total subpeaks  \
# 0   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 1   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 2   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 3   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 4   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 5   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 6   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 7   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 8   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 9   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 10  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 11  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 12  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 13  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 14  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 15  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 16  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 17  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 18  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 19  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 20  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 21  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 22  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 23  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 24  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 25  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 26  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 27  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 28  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 29  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 30  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 31  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 32  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 33  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 34  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 35  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 36  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 37  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 38  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 39  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 40  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 41  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 42  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 43  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 44  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 45  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 46  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 47  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 48  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
# 49  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               1
#
#    /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t00.txt  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t15.txt  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t60.txt
# 0                                          chr14-3108
# 1                                          chr14-3109
# 2                                          chr11-4861
# 3                                          chr11-4862
# 4                                          chr11-4863
# 5                                          chr11-4864
# 6                                          chr11-4869
# 7                                           chr1-9132
# 8                                           chr1-9133
# 9                                           chr1-9134
# 10                                          chr1-9135
# 11                                          chr3-3931
# 12                                          chr1-9136
# 13                                          chr3-3932
# 14                                          chr1-9138
# 15                                          chr3-3934
# 16                                          chr3-3935
# 17                                         chr1-10610
# 18                                         chr1-10612
# 19                                         chr11-3260
# 20                                         chr11-3264
# 21                                         chr1-10619
# 22                                         chr11-3265
# 23                                         chr11-3267
# 24                                         chr11-3269
# 25                                          chr3-2331
# 26                                          chr3-2332
# 27                                          chr3-2333
# 28                                          chr3-2336
# 29                                          chr3-2338
# 30                                         chr14-3113
# 31                                         chr14-3114
# 32                                         chr14-3117
# 33                                         chr14-3118
# 34                                         chr14-3119
# 35                                         chr11-4870
# 36                                         chr11-4871
# 37                                         chr11-4872
# 38                                         chr11-4873
# 39                                         chr11-4874
# 40                                         chr11-4875
# 41                                         chr11-4876
# 42                                         chr11-4877
# 43                                         chr11-4878
# 44                                          chr1-9140
# 45                                          chr1-9141
# 46                                          dm6_X-258
# 47                                          chr1-9144
# 48                                          chr3-3940
# 49                                          chr1-9145

# %%
dat.dropna()
# Out:
#        #name (cmd = mergePeaks /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t00.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t15.txt /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t60.txt -strand)  \
# 96868                             Merged-dm6_X-13411509-3
# 96869                             Merged-dm6_X-13411613-3
# 96870                             Merged-dm6_X-17710139-3
# 96871                             Merged-dm6_X-17710202-3
# 96872                             Merged-dm6_X-19353236-3
# ...                                                   ...
# 125295                            Merged-chr10-73730518-3
# 125296                             Merged-chr5-40755566-3
# 125297                            Merged-chr7-101217679-3
# 125298                              Merged-chr9-4490426-3
# 125299                            Merged-chr8-143942665-3
#
#           chr      start        end strand        Stat  \
# 96868   dm6_X   13411419   13411592      +   11.800000
# 96869   dm6_X   13411538   13411688      -   12.653333
# 96870   dm6_X   17710064   17710214      +   15.433333
# 96871   dm6_X   17710111   17710291      -   14.433333
# 96872   dm6_X   19353141   19353352      -   12.866667
# ...       ...        ...        ...    ...         ...
# 125295  chr10   73730383   73730698      -  101.833336
# 125296   chr5   40755425   40755745      +   10.320000
# 125297   chr7  101217506  101217809      -  116.166664
# 125298   chr9    4490256    4490570      -   56.633331
# 125299   chr8  143942504  143942849      +   33.643333
#
#                                              Parent files  Total subpeaks  \
# 96868   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 96869   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 96870   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 96871   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 96872   /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# ...                                                   ...             ...
# 125295  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 125296  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 125297  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 125298  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
# 125299  /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_ho...               3
#
#        /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t00.txt  \
# 96868                                           dm6_X-240
# 96869                                           dm6_X-241
# 96870                                           dm6_X-242
# 96871                                           dm6_X-243
# 96872                                           dm6_X-244
# ...                                                   ...
# 125295                                          chr10-818
# 125296                                          chr5-2302
# 125297                                           chr7-423
# 125298                                           chr9-991
# 125299                                           chr8-929
#
#        /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t15.txt  \
# 96868                                           dm6_X-279
# 96869                                           dm6_X-241
# 96870                                           dm6_X-176
# 96871                                           dm6_X-187
# 96872                                           dm6_X-237
# ...                                                   ...
# 125295                                          chr10-792
# 125296                                          chr5-2512
# 125297                                           chr7-708
# 125298                                           chr9-847
# 125299                                          chr8-1094
#
#        /gpfs/fs1/data/reddylab/Kuei/Dex_PROcap/run_homer/out_findPeak/tss_t60.txt
# 96868                                           dm6_X-296
# 96869                                           dm6_X-284
# 96870                                           dm6_X-221
# 96871                                           dm6_X-230
# 96872                                           dm6_X-234
# ...                                                   ...
# 125295                                          chr10-242
# 125296                                          chr5-3120
# 125297                                          chr7-1241
# 125298                                          chr9-1021
# 125299                                          chr8-2636
#
# [28432 rows x 11 columns]
