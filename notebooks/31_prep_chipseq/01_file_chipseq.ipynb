# %%
ls /data/reddylab/projects/ggr/data/chip_seq/
# Out:
# mapped_reads  peak_overlap  QC		    quantification_across_factors
# metadata      peaks	    quantification  trimmed_reads

# %% [markdown]
# All the peak files can be access via:
# ```
# ls /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.*.dedup.masked.sorted_peaks.narrowPeak
# ```

# %% [markdown]
# There are 659 peak files in totla

# %%
fpath=/data/reddylab/projects/ggr/data/chip_seq/peaks/A549.*.dedup.masked.sorted_peaks.narrowPeak
ls -1 $fpath | wc -l
# Out:
# 659

# %% [markdown]
# For example, cJun has both short term and long term treatments ChIP-seq results

# %%
ls /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.*rep1.dedup.masked.sorted_peaks.narrowPeak
# Out:
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h05m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h10m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h15m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h20m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h25m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h30m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# ...

# %%
ls /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.*rep1.dedup.masked.sorted_peaks.narrowPeak
# Out:
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h05m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h10m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h15m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h20m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h25m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h30m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.01h.rep1.dedup.masked.sorted_peaks.narrowPeak
# ...

# %%
ls -l /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# Out:
# lrwxrwxrwx. 1 ter18 reddylab 84 Dec 20  2017 /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak -> /data/reddylab/projects/GGR//data/chip_seq/peaks/iter0/GR.t00m_rep1_peaks.narrowPeak

# %%
ls -l /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# Out:
# lrwxrwxrwx. 1 ter18 reddylab 83 Dec 20  2017 /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak -> /data/reddylab/projects/GGR//data/chip_seq/peaks/iter0/GR.t00_rep1_peaks.narrowPeak

# %%
ls -l /data/reddylab/projects/ggr/data/chip_seq/mapped_reads/A549.GR.dex*00h*rep1*rpkm.bw
# Out:
# lrwxrwxrwx. 1 ter18 reddylab        97 Dec 20  2017 /data/reddylab/projects/ggr/data/chip_seq/mapped_reads/A549.GR.dex.00h00m.rep1.dedup.masked.sorted.rpkm.bw -> /data/reddylab/projects/GGR//data/chip_seq/quantified_read_counts/iter_short/GR.t00m_rep1.rpkm.bw
# lrwxrwxrwx. 1 ter18 reddylab       101 Dec 20  2017 /data/reddylab/projects/ggr/data/chip_seq/mapped_reads/A549.GR.dex.00h00m.rep1redo.dedup.masked.sorted.rpkm.bw -> /data/reddylab/projects/GGR//data/chip_seq/quantified_read_counts/iter_short/GR.t00m_rep1redo.rpkm.bw
# lrwxrwxrwx. 1 ter18 reddylab        97 Dec 20  2017 /data/reddylab/projects/ggr/data/chip_seq/mapped_reads/A549.GR.dex.00h05m.rep1.dedup.masked.sorted.rpkm.bw -> /data/reddylab/projects/GGR//data/chip_seq/quantified_read_counts/iter_short/GR.t05m_rep1.rpkm.bw
# ...

# %%
ls -l /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00m_rep1_peaks.narrowPeak
# Out:
# -rw-rw-r--. 1 ter18 reddylab 9799 Jul 19  2017 /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00m_rep1_peaks.narrowPeak

# %%
ls -1 /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00m*
# Out:
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00m_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00m_rep1_peaks.xls
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00m_rep1_treat_pileup.bdg

# %%
ls -1 /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t*m_rep1_peaks.narrowPeak
# Out:
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00m_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t05m_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t10m_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t15m_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t20m_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t25m_rep1_peaks.narrowPeak

# %%
ls -1 /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t0?_rep1_peaks.narrowPeak
ls -1 /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t?_rep1_peaks.narrowPeak
# Out:
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t00_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t05_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t1_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t2_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t3_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t4_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t5_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t6_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t7_rep1_peaks.narrowPeak
# /data/reddylab/projects/GGR/data/chip_seq/peaks/iter0/GR.t8_rep1_peaks.narrowPeak

# %% [markdown]
# ## Short Term Dex response

# %% [markdown]
# - cJun
# - EP300
# - GR
# - H3K27ac
# - RAD21
# - SMC3

# %%
fpath=/data/reddylab/projects/ggr/data/chip_seq/peaks/A549.*.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
ls -1 $fpath
# Out:
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.EP300.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.H3K27ac.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.RAD21.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.SMC3.dex.00h00m.rep1.dedup.masked.sorted_peaks.narrowPeak

# %% [markdown]
# ## Long Term Dex response

# %%
fpath=/data/reddylab/projects/ggr/data/chip_seq/peaks/A549.*.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
ls -1 $fpath
# Out:
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.CEBPB.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.cJun.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.CTCF.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.EP300.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.FOSL2.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GR.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.GRIP1.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.H3K27ac.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# ...

# %%
ls /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.*.dedup.masked.sorted_peaks.narrowPeak
# Out:
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.00h30m.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.00h30m.rep2.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.00h30m.rep3.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.00h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.00h.rep2.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.00h.rep3.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.01h.rep1.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.01h.rep2.dedup.masked.sorted_peaks.narrowPeak
# /data/reddylab/projects/ggr/data/chip_seq/peaks/A549.BCL3.dex.01h.rep3.dedup.masked.sorted_peaks.narrowPeak
# ...
